# %%
print("Hello!")
# Out:
# Hello!

# %%
print(":)")
# Out:
# :)

# %%
print("Something something, I can totally code")
# Out:
# Something something, I can totally code

# %% [markdown]
# The above is a couple lines of code to test out github coding again ^
