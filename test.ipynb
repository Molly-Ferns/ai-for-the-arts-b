# %%
print("Hello!")
# Out:
# Hello!

# %%
print(":)")
# Out:
# :)

# %%
print("Something something, I can code")
# Out:
# Something something, I can code

# %% [markdown]
# The above lines of code were done to test out github coding again and make sure I understand how to print messages.

# %% [markdown]
# <h2>Does the best AI and best human lead to the best collaboration?</h2>
#
# <p>The first source given in the lab book explored how AI should augment human learning and intelligence, through the right methods which focus on learning rather than AI reliability.</p>
# <p>Others in my peer group seemed to agree with this idea, however there was also consistent thought that people could augment their own learning independantly, and that other factors such as environemental and social impact of AI may be a driving force to collective reliability on such,  and therefore a hindereance to learning and work.</p>
# <p>I raised the point that the 'best' collaboration can depend on what work is being done, and that research specifically can be augemented by the help of automatic processing of difficult questions and calculations.</p>

# %% [markdown]
# <h2>Working with Cultural Heritage</h2>
#
# <p>Tasks:</p>
# <li>Identify your topic. It could be about a historical figure, a famous cultural artifact, or a scientific concept.</li>
#
# <li>Explore the background of your identified topic. You can do this manually or get the help of AI tools. But always incorporate fact checking into your process.</li>
#
# <li>Experiment with Generative AI tools. I used image generation above but yours can be text generation, audio generation or even video generation or something else altogether.</li>
#
# <li>Identify some initial objectives/ideas. Generating images and exploring the background of the topic I selected allowed me to understand the scope of relevant areas and possible avenues for engaging the public and for learning and discovery! Do the same with your topic.</li>

# %%
<h2>Exploring Other Tools</h2>

# %% [markdown]
# <h3>Understanding Digitisation</h3>

# %% [markdown]
# <h3>Reflection on Creativity</h3>

# %% [markdown]
# <h2>Guidelines for developing project idea</h2>

# %% [markdown]
# <h3>Establishing the context</h3>

# %% [markdown]
# <b>Idea for project using GAI:</b>
# <p>First one with letter and word drawings, using gen AI as a means of translation for letter and drawing meanings, also focused on accesibility through explination of where/what/how these were acquired.</p>
# <p>Focusing on this because it is something GAI would be more useful for than any other tool and can be done quickly, allowing for a feasible project scope.</p>
#
# <b>Questions</b>
# <li>What is the object? In particular, can you find out any information about its origin, history or use?</li>
# <p>The object is refered to as as, 'Illuminations on vellum: capital letters, ornaments.' It is also simply referred to as a volume of initial letters manuscript.</p>
# <p>From the UofG Collections Page, I found that it was extracted from a 14th century Carmelite missal. It use, while not entirely clear, its extensive representation of different lettering may encourage many forms of creativity to develop alongside it.</p>
# <li>What is the value of the object? What distinguishes it, why is it interesting, and/or who would it be of interest to?</li>
# <p>The objects value could be derived from how old it is - assumed to be at least from the 14th century. As well as this the object can be traced from an imperfect missal, which would hold many high value collections at this time.</p>
# <p>It is distinguished by its noticebale oatterns on its cover, as well as its easily recognisable patterns inside it. Its deep colours and small, detailed designs would be of interest to designers, artists, and language students.</p>
# <li>Are there other known objects that are similar or are related to the object by context, history or origin?</li>
# <p>According to UofG Collections, two volumes (as a part of a larger election of this) was sold in 1833 of which is owned today by The British Library Department of Manuscripts.</p>
# <li>What collection is it part of? Where is it stored?</li>
# <p>This object is stored in the UofG Archives and Special Collections Department, in its manuscripts collections. Its reference code is GB 247 MS Euing 26, and is available to examine the outside of it through the UofG collections website. Physical access is available through appointment.</p>

# %% [markdown]
# <h3>AI-Human Interaction</h3>

# %% [markdown]
# <p>Reflect on the relationship between AI generated content and content generated by you. You might want to think of them as informing each other in a feedback loop, or complementing each by carrying out different parts with a shared end-goal, rather than independent and/or discrete activities. Draw a diagram of the process and then compare with your group.</p>

# %% [markdown]
# <h3>Combining Data</h3>

# %% [markdown]
# <li>How do the generated data and original data created from the object come together to meet the objectives for which you selected the collection object? How effectively does it engage your audience or stimulate their thinking?</li>
#
# <p>The original data from my object will help me understand what it is that I would like to translate and evaluate for those who can't. Generated data will be used interpret parts of my object which are not immediately understandable, or have creative points of reference that could be analysed further.</p>
#
# <p>On its own, audiences may not be too engaged in simply understanding the thought process in one or two drawings. For this reason I will also use GenAI to build a story upon the letterings that are shown; i.e., identify repeated symbols, identify what changes within miniscule lettering, and how different colours are paired to create a sense of emotion.</p>
#
# <li>Reflect on the Lovelace-Boden-Ridler Test discussed in Week 1. Are there other angles that this framework misses?</li>
#
# <p>
#
# <li>Reflect on the full criteria for the evaluation report on the Moodle. How would you evaluate the project for creativity? Why?</li>
#
# <p>

# %% [markdown]
# <h3>Planning Evaluation</h3>
#
# <p>Reflecting on my evaluation...
