# %% [markdown]
# <h2>1. Introduction and Context</h2>
#
# <p><mark>Click <a href="https://www.gla.ac.uk/collections/#/details?irn=260822&catType=C">here</a> to see the object yourself!</mark></p>
#
# <p>The object chosen for this project is <b>GB 247 Euing 26</b>, <i>Illuminations on vellum</i>, 1300-1833. This is a manuscript extracted from a 14th Century Carmelite, showcasing large printed alphabetical letters and designs. The language is in Latin (according to the Glasgow University Archives page), which can also been seen through multiple unrecognizable letter designs in the object.</p>
#
# <p>The Glasgow University Archives page also tells us that the author of this object is <b>Esther Cory</b>; who is said to have assembelled the collection in the early nineteenth century (Cleaver et al., 2024). This collection was then sold in 1857 after a disposal of book collector <b>Philip Hanrott's</b> library, following his death - then finally bequeathed from <b>William Euing</b> to <b>Glasgow University Library</b>, where it remains to this day (Connolly, 2022).<p>
#
# <h4><u>"Why this object?", and the Lovelace-Boden-Ridler Test</u></h4>
#
# <p>I chose this object due to the unique creativity which it exhibited. As you can see, even one letter was given a considerable amount of time and effort into its design, despite how similar it may be from the last. Letters which we don't or do recognise alike are made with delicate designs worth understanding.</p>
#
# <p>The objective of combining generative AI with this object is to understand deeper what context these pieces were made in, what certain symbols mean, and to determine how AI and human collaboration can result in something new, or perhaps even 'creative'. This will be done with direct reference to the <b>Lovelace-Boden-Ridler</b> test.</p>
#
# <p><mark>NOTE: the pictures aren't in the github yet, but they're in the folder you made on the uni computer.</p></mark>
#
# <p>The Lovelace-Boden-Ridler test...</p>
#
# <p>Boden (2003)</p>
#
# <p>Therefore, the full objectives of this project are as follows:</p>
#
# <li>Understand further what certain letters and designs could mean or relate to,</li>
# <li>Gain a better understanding of the context behind the object,</li>
# <li>Relate the work of Ms Euing 26 to other creative outputs today made by humans,
# <li>Educate audiences on how AI can augment creative processes,</li>
# <li>Determine whether human and AI collaboration is capable of passing the Lovelace-Boden-Ridler test, as discussed.</li>
#
# <h2>2. Methodology</h2>
#
# <p>To reach the established objectives of this project, the human creative processes of sound, image, and text generation was an output I intended to demonstrate. To do this, the GAI (Microsoft Copilot and DALL-E 2) was asked to determine the meaning and language of latin-based letter designs. These models were also asked to evaluate the drawings inside of these characters - what they depict, what they mean, and if they can relate to any real events or depictions that we know of already.<p>
#
# <p>To  further understand the meaning of the text in this object, the GAI(s) were then asked to create a transcription of the letters which I do not recognize, and then asked to analyse what the meanings of these are. This  was done so that, when relating this object to other works, there was a baseline of latin which was now known to be in this object.</p>
#
# <p>Finally, these outputs will be analysed and discussed in reference to how it relates to human creativity, and how these processes augmented not only our understanding of the object, but also our view of creativity as a whole.</p>
#
# <p><u>What is generative AI? Why Copilot and DALL-E 2 Will Be The Tools Used</u></p>
#
# <p>Generative AI is...</p>
#
# <p>AI algorithms, training/test data, input/output regarding machine learning workflow.</p>
#
# <p>Microsoft Copilot and DALL-E 2 are appropriate academically because..</p>
#
# <p>Microsoft Copilot is appropriate given other tool options because its database is far wider regarding users content input. As this project is partially focused on relating the work to others done today, it is vital that there is oppurtunity for the most works to be considered. <mark>please fact check this</mark></p>
#
# <p>DALL-E 2, as used in (chatgpt/openai), is a primarily image-based model which will be used for the main purpose of generating images based on the objects language and drawing desgins - by asking it to make certain images clearer, we can also gain a deeper understanding of the story or meaning behind these drawings.</p>
#
# <p><u>Accuracy</u></p>
#
# <p><u>Explanation and Context</u></p>
#
# <p>Working relationships were developed with eppers over critical analysis of each others plans...</p>
#
# <h2>3. Output Results and Discussion</h2>
#
# <p><u>Output of Context</u></p>
#
#
#
# <p><u>Output of Text, Translation, and Transcription</u></p>
#
# <p><u>Output of Image Analysis</u></p>
#
# <p><u>Output of Image Generation</u></p>
#
# <p><u>Output of Relations to Other Works</u></p>
#
# <p><u>Discussion</u></p>
#
# <h2>Conclusion</h2>
